# %% [markdown]
# # 5. Calendar e invitaciones\n

# %% [markdown]
# Primero se consulta disponibilidad. La creación de la invitación\n                se deja comentada para evitar eventos accidentales.\n

# %%
from src.calendar import consultar_disponibilidad\n\n                opciones = [\n                    {\n                        "dia": "martes",\n                        "hora_desde": "17:30",\n                    },\n                    {\n                        "dia": "miércoles",\n                        "hora_desde": "17:30",\n                    },\n                ]\n\n                print(\n                    consultar_disponibilidad(\n                        opciones,\n                        duracion_minutos=60,\n                    )\n                )\n

# %%
# Ejemplo de creación real:\n                #\n                # from src.calendar import crear_invitacion_calendar\n                #\n                # resultado = crear_invitacion_calendar(\n                #     message_id="ID_REAL_DEL_CORREO",\n                #     titulo="Reunión con el AMPA",\n                #     opcion={\n                #         "fecha": "2026-07-01",\n                #         "hora_desde": "17:30",\n                #     },\n                #     duracion_minutos=60,\n                # )\n                #\n                # print(resultado)\n
