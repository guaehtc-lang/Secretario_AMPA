# %% [markdown]
# # 2. Tools, funciones y agente\n

# %% [markdown]
# Se revisan por separado las tres piezas del patrón de clase:\n                mensajes, tools y funciones.\n

# %%
from src.funciones import funciones\n                from src.tools import tools\n\n                print("Tools:")\n                for tool in tools:\n                    print("-", tool["function"]["name"])\n\n                print("\nFunciones:")\n                for nombre in funciones:\n                    print("-", nombre)\n

# %%
from src.agente import ejecutar_agente\n                from src.prompt import crear_mensajes\n\n                mensajes = crear_mensajes()\n\n                # La ejecución completa se hará al final:\n                # print(ejecutar_agente(mensajes, tools, funciones))\n
