# %% [markdown]
# # 01 - Configuración

# %%
from src.parametros import LLM_MODEL, TIMEZONE, COMPOSIO_USER_ID

print("Modelo:", LLM_MODEL)
print("Zona horaria:", TIMEZONE)
print("Usuario Composio:", COMPOSIO_USER_ID)
