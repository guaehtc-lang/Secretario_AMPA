# %% [markdown]
# # 1. Configuración y primera llamada\n

# %% [markdown]
# Este notebook comprueba las variables del proyecto y realiza\n                una llamada sencilla al LLM siguiendo el estilo visto en clase.\n

# %%
from openai import OpenAI\n\n                from src.parametros import API_KEY, BASE_URL, MODELO\n\n                cliente = OpenAI(\n                    api_key=API_KEY,\n                    base_url=BASE_URL,\n                )\n\n                respuesta = cliente.chat.completions.create(\n                    model=MODELO,\n                    messages=[\n                        {\n                            "role": "user",\n                            "content": "Responde: configuración correcta.",\n                        }\n                    ],\n                )\n\n                print(respuesta.choices[0].message.content)\n
