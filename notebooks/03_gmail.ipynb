# %% [markdown]
# # 03 - Gmail
# Ejecutar después de autorizar Google.

# %%
from src.gmail import obtener_correos_no_leidos

correos = obtener_correos_no_leidos()
print("Correos pendientes:", len(correos))
for correo in correos:
    print(correo["fecha"], "-", correo["asunto"])

# %% [markdown]
# La creación de borradores y el marcado como leído se prueban desde `main.py`.
