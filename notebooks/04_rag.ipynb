# %% [markdown]
# # 4. Histórico y RAG\n

# %% [markdown]
# Primero se carga el histórico y después se prueba una búsqueda.\n                El número de años se controla desde parametros.py o .env.\n

# %%
from src.parametros import RAG_ANIOS_HISTORIAL\n                from src.rag import actualizar_rag\n\n                print("Años de histórico:", RAG_ANIOS_HISTORIAL)\n\n                # Ejecutar una sola vez cuando se quiera actualizar:\n                # print(actualizar_rag())\n

# %%
from src.rag import buscar_contexto_rag\n\n                resultado = buscar_contexto_rag(\n                    "inscripción y cuota del AMPA"\n                )\n\n                print(resultado)\n
