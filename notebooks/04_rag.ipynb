# %% [markdown]
# # 04 - RAG separado

# %%
from src.rag import actualizar_rag, consultar_rag

# Ejecutar una vez para construir el RAG
# print(actualizar_rag())

print(consultar_rag("inscripción y cuota del AMPA"))
