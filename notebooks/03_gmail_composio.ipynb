# %% [markdown]
# # 3. Gmail con Composio\n

# %% [markdown]
# Prueba aislada de lectura. No crea borradores ni modifica Gmail.\n

# %%
from src.gmail import leer_correo_pendiente\n\n                resultado = leer_correo_pendiente()\n                print(resultado)\n
