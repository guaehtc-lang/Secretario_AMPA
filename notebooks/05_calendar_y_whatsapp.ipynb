# %% [markdown]
# # 05 - Calendar y WhatsApp simulado

# %%
from src.calendar import consultar_disponibilidad
from src.whatsapp import enviar_whatsapp

# Ejemplo Calendar
# opciones = [{"dia": "martes", "hora": "17:30"}]
# print(consultar_disponibilidad(opciones))

# Ejemplo WhatsApp simulado
# print(enviar_whatsapp("prueba_001", "Riesgo en el patio. Revisar correo original.", "riesgo_fisico"))
